# %% [markdown]
# <a href="https://colab.research.google.com/github/DarkEyes/RC-Arch/blob/main/idu_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IDU — Computational Demonstration
#
# Reproducible demonstrations for the residual-adequacy architecture. Linear instance; fully deterministic. Run cells top to bottom.

# %% [markdown]
# ## 1. Typed abstention — three witnessed terminals from one engine

# %%
# %run demo_abstention.py
# Out:
# ...
# DEMONSTRATION 1 -- TYPED ABSTENTION (one engine, three inputs)
# ...
#
# (i  conflict)  c=[1. 1. 0. 0.]
#    active regimes = ['summarize', 'advocate']
#    -> [freeze_time] X={'timeout': {'conflict': [('emit_advocacy', 'emit_summary')]}} regimes=['summarize', 'advocate'] acts=['emit_advocacy', 'emit_summary']
#
# (ii unrepresentable)  c=[0. 0. 5. 0.]
#    active regimes = []
#    -> [freeze_resid] X={'resid_coords': [2]} regimes=[] acts=[]
#
# (iii values stop)  c=[0. 0. 0. 1.]
#    active regimes = ['policy']
#    -> [freeze_halt] X={'halt_regimes': ['policy']} regimes=['policy'] acts=['HALT']
#
# ----------------------------------------------------------------------
# One configuration, three contents, three witnessed terminal TYPES.

# %% [markdown]
# ## 2. Bounded empathy — agreement vs. localized divergence

# %%
# %run demo_empathy.py
# Out:
# ...
# DEMONSTRATION 2 -- BOUNDED EMPATHY
# ...
#
# Shared label 'pain'; private weightings differ by angle 33.4 deg
#
# Content sweep (A predicts B with A's weighting; B acts with B's):
#          content     A pred     B real  match
#          [1. 0.]    imaging    imaging  OK
#        [0.9 0.1]    imaging    imaging  OK
#        [0.8 0.2]    imaging    imaging  OK
#        [0.7 0.3]    imaging    imaging  OK
#        [0.6 0.4]    imaging   referral  DIVERGE
#        [0.5 0.5]    imaging   referral  DIVERGE
#        [0.4 0.6]    imaging   referral  DIVERGE
#        [0.3 0.7]   referral   referral  OK
#        [0.2 0.8]   referral   referral  OK
#        [0.1 0.9]   referral   referral  OK
#          [0. 1.]   referral   referral  OK
#
# Actions agree on 14/21 sampled contents; diverge on 7.
# Divergence appears only in the ambiguous band [0.65 0.35] ... [0.35 0.65];
# clear-cut injury or psychosomatic content yields agreement.
# ...

# %% [markdown]
# ## 3. Developmental prerequisites — stuck → learnable, agent-relative

# %%
# %run demo_prerequisites.py
# Out:
# ...
# DEMONSTRATION 3 -- DEVELOPMENTAL PREREQUISITES (real study-step attempts)
# ...
#
# BEFORE: holds {function-notation}, w=1
#    held regimes = ['function']
#    unrepresented residual coords = [1, 2, 3]
#    focus window F (w=1) = [1]
#    study step -> residual spans 3 coords > w=1; no admissible edit -> STUCK
#
# AFTER: holds {function-notation, algebra, limits}, w=1
#    held regimes = ['algebra', 'function', 'limits']
#    unrepresented residual coords = [3]
#    focus window F (w=1) = [3]
#    study step -> admissible edit exists; residual fits in window -> LEARNABLE
#
# WIDER FOCUS: holds {function-notation}, w=3
#    held regimes = ['function']
#    unrepresented residual coords = [1, 2, 3]
#    focus window F (w=3) = [1, 2, 3]
#    study step -> admissible edit exists; residual fits in window -> LEARNABLE
#
# ----------------------------------------------------------------------
# stuck before acquisition: True
# learnable after acquiring algebra+limits: True
# ...

# %% [markdown]
# ## 4. Figure (three panels)

# %%
# %run make_figure.py
from IPython.display import Image
Image('demo_figure.png')
# Out:
# wrote demo_figure.png
